# %% [markdown]
# <div style="background-color:rgb(0,40,69);  padding:40px 0;">
#  <img src="https://cic.tec.mx/cic/templates/img/logotec2019.png"><img>
#  <p style="font-size:400%; color:white; text-align:center;font-weight: bold;">PROYECTO</p>
#      <p style="font-size:400%; color:white; text-align:center;font-weight: bold;">MACHINE <span style="color:rgb(0, 207, 204)">LEARNING:</span></p>
#      <p style="font-size:400%; color:white; text-align:center;font-weight: bold;">AVANCE 2</p>
#     <br>
#     <br>
#     <p style="font-size:200%; color:white; text-align:center;font-weight: bold;">TC2006 Lenguajes de programación</p>
#     <br>
#     <br>
#     <p style="font-size:200%; color:white; text-align:center;">Profesora: Astrid Alcaraz</p>
#     <p style="font-size:200%; color:white; text-align:center;">Periodo Ago - Dic 2020</p>
#     <br>
#     <br>
#     <p style="font-size:200%; color:white; text-align: center;">Jaime Solis &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; A00759756</p>
#     <p style="font-size:200%; color:white; text-align: center;">Jesús Ruiz &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  A00758756</p>
#
#
#
# </div>

# %% [markdown]
# ## Contenido
#
# * [Introducción](#Introducción)
#     * [Tipos de Aprendizaje](Tipos-de-Aprendizaje)
#         * [Supervisado](#Supervisado)
#         * [No Supervisado](#No-Supervisado)
#         * [Semi Supervisado](#Semi-Supervisado)
#         * [Aprendizaje por Refuerzo](#Aprendizaje-por-Refuerzo)
# * [Definición del proyecto](#Definición-del-proyecto)
# * [Tecnologías empleadas](#Tecnologías-empleadas)
#     * [Python](#Python)
#     * [Anaconda](#Anaconda)
#     * [Jupyter](#Jupyter)
#     * [Numpy](#Numpy)
#     * [Pandas](#Pandas)
#     * [MatplotLib](#MatplotLib)
# * [Tema a desarrollar](#Tema-a-desarrollar)
# * [Dataset Seleccionado](#Dataset-seleccionado)
#    * [Referencia al repositorio de extracción](#Referencia-al-repositorio-de-extracción)
#    * [Descripción del dataset](#Descripción-del-dataset)
#         * [Descripción de variables](#Descripción-de-variables)
# * [Librerías](#Librerías)
# * [Preprocesamiento de Datos](#Preprocesamiento-de-Datos)
# * [Referencias](#Referencias)

# %% [markdown]
# ## Introducción
#
# <img style="height: 300px; float:left;" src='https://uploads.toptal.io/blog/image/443/toptal-blog-image-1407508081138.png'>
#
# El aprendizaje automático *(Machine Learning)* es sin lugar a dudas una de las tecnologías más influyentes y poderosas del mundo actual. Pero lo más importante es saber que, aún estamos lejos de ver todo su potencial.
#
# Esta herramienta es utilizada para convertir la información en conocimiento. Hoy se están generando más datos que nunca y la cantidad de información generada diariamente seguirá creciendo. De acuerdo a IBM[<sup>1</sup>](#Barranco), en 2012 se generaban 2.5 exabytes (2.5 x 10<sup>18</sup> bytes). Entre 2013 y 2020, IDC[<sup>2</sup>](#Patrizio) estima que entre 2013 y 2020, la cantidad de dato que generamos incrementó de 4.4 zettabytes a 44 zettabytes y para 2025, se esperan 175 zettabytes de datos[<sup>2</sup>](#Zb). Pero esta masa de datos es inútil a menos que sea analizada y se encuentren patrones ocultos en su interior. Las técnicas de ML se utilizan para encontrar automáticamente los patrones dentro de datos complejos que, de otro modo, nos costaría descubrir. Los patrones ocultos y el conocimiento sobre un problema se pueden utilizar para predecir eventos futuros y realizar todo tipo de toma de decisiones.
#
# La mayoría de nosotros no sabemos que la Ciencia de Datos es utilizada todos los días. Cada vez que buscamos algo en *Google*, escuchamos una canción en *Spotify* o incluso tomamos una foto, el aprendizaje automático se está convirtiendo en parte del motor detrás, aprendiendo y mejorando constantemente con cada interacción. ML también está detrás de los avances que cambian al mundo como la detección del cáncer, la creación de nuevos medicamentos y los vehículos autónomos.
#
# Tradicionalmente, la ingeniería de software combina reglas, creadas por personas, con datos para crear respuestas a un problema. En cambio, Machine Learning utiliza datos y respuestas para descubrir reglas detrás de un problema *(Chollet, 2018)*.
#
# Para aprender las reglas que gobiernan un fenómeno, las máquinas deben pasar por un proceso de aprendizaje, probar diferentes reglas y aprender que también funcionan. Por lo tanto se conoce como aprendizaje automático o Machine Learning. Su objetivo es crear un modelo entrenado con una gran cantidad de datos que nos permita resolver una tarea. El modelo aprende de los datos y es capaz de hacer predicciones.
#
#
#
#
# ### Tipos de Aprendizaje
#
# Existen múltiples formas de aprendizaje: supervisado, no supervisado y aprendizaje por refuerzo. Cada forma de aprendizaje tiene enfoques y algoritmos diferentes, pero todos siguen el mismo proceso y teoría subyacentes.
# <img style="width: 100%;" src='https://brianasimba.github.io/MachineLearningblog/images/ML_branches.png'>
#
#
#
# #### Supervisado
# En el método supervisado, los datos de entrenamiento tienen una variable que etiqueta el resultado o clase de cada instancia. Una tarea típica del aprendizaje supervisado es de clasificación. El filtro de *spam* del correo electrónico es un ejemplo de este. El modelo es entrenado con muchos ejemplos de correos junto con la clase (*spam* o *ham*) y este aprende cómo clasificar nuevos correos. Regresión es otra aplicación en la que el objetivo del modelo es predecir valores (valor de acciones, precio de casas, etc).
#
# #### No Supervisado
# El aprendizaje no supervisado no incluye la etiqueta de clases, el modelo tiene que aprender solo a separar los datos y agruparlos. Un uso común es usar un algoritmo de *clustering* para detectar grupos de clientes similares para campañas de marketing. La detección de anomalías es otra tarea no supervisada, es usada para detectar fraudes con tarjetas de crédito, identificar fallas de manufactura, hacer limpieza de datos, etc.
#
# #### Semi Supervisado
# También está el aprendizaje semi supervisado que es una mezcla de los dos anteriores porque la mayoría de los datos no están etiquetados. Un ejemplo de esto es el reconocimiento facial de *Google Photos* ya que cuando se etiqueta a una persona en una foto, la aplicación nos puede mostrar todas las fotografías con esa persona.
#
# #### Aprendizaje por Refuerzo
# El aprendizaje por refuerzo es muy diferente ya que en este caso, el sistema es expuesto a una situación donde puede elegir una acción. De acuerdo a la acción tomada, el sistema es recompensado o penalizado y entonces el modelo se actualiza con cómo toma las decisiones. El proceso se repite hasta que se llega a una solución óptima. Los sistemas inteligentes generalmente usan este tipo de aprendizaje.
#
#
# Otros ejemplos de aplicaciones de *Machine Learning* son:
#
#  - Análisis de sentimiento para reseñas de *Amazon* o *posts* en redes sociales
#  - Resumir documentos automaticamente
#  - Predecir las ventas futuras de una empresa
#  - Creat *chatbots* o asistentes personales
#  - Segmentar clientes
#  - Recomendar productos basados en el historial de consumo
#
# El objetivo de este proyecto es hacer uso de diferentes algoritmos y herramientas de ML para crear modelos predictivos aplicados.
#
# ---
#
# <p id="Barranco"><a href="https://developer.ibm.com/es/technologies/data-science/articles/que-es-big-data/" target="_blank"><sup>1</sup> (Barranco, R., 2010)</a></p>
# <p id="Patrizio"><a href="https://www.networkworld.com/article/3325397/idc- expect-175-zettabytes-of-data-worldwide-by-2025.html" target="_blank"><sup>2</sup> (Patrizio, A., 2018)</a></p>
# <p id="Zb"><sup>3</sup> 1 ZB = 10<sup>21</sup> bytes = 1,000,000,000,000,000,000,000 bytes</p>

# %% [markdown]
# ## Definición del proyecto
#
#
# Dado que el enorme conjunto de datos generado en todo el mundo relacionado con la pandemia de COVID-19, todos los días puede extraerse y analizarse información para obtener conocimientos útiles y válidos para extraer patrones para una mejor toma de decisiones que ayuden a contener el brote de la pandemia.
#
# En el sector de la salud, la minería de datos se ha aplicado ampliamente en muchas aplicaciones diferentes[<sup>1</sup>](#Al), como la predicción de los resultados de los pacientes, la clasificación de los hospitales y la evaluación de la efectividad del tratamiento y el control, la estabilidad y la recuperación de infecciones.
#
# En este proyecto se desarrollarán modelos de aprendizaje supervisado para **predicir si un paciente se recuperará o perderá la vida debido al virus SARS-CoV-2**, por lo que es un problema de clasificación. También se intentará la posibilidad de construir un modelo que prediga el tiempo de recuperación, esto sería un problema de regresión.
#
# Estos modelos podrían servir al personal del área de salud para determinar la recuperación y estabilidad de las personas recién infectadas de la pandemia de COVID-19. Los modelos se desarrollarán con el conjunto de datos obtenido del Portal de Datos Abiertos del Gobierno de la República de Mexicana, lo cuál se explicará más adelante.
#
# Se buscará implementar algoritmos de ML como árboles de decisión, SVMs, naive Bayes, random forests, regresión lógistica, KNNs o Redes neuronales utilizando el lenguaje de programación Python así como diversas librerías que se explicarán en la siguiente sección.
#
# ---
#
# <p id="Al"><a href="https://doi.org/10.1016/j.jiph.2016.09.007" target="_blank"><sup>1</sup> (Al-Turaiki, I., Alshahrani, M., & Almutairi, T, 2016)</a></p>

# %% [markdown]
# ## Tecnologías empleadas
#
# ### Python
# <img align='left' style="height: 60px;" src='https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png'>
#
# *Python* es un lenguaje que se ve favorecido por su legibilidad y curva de aprendizaje relativamente sencilla. Se han desarrollado varios módulos para facilitar el desarrollo de aplicaciones ML utilizando *python*. La instalación de los módulos se puede llevar a cabo a través de *pip*. Varios de estos módulos son reconocidos por sus usos en este tipo de implementaciones, tales como *numpy*, *scipy*, o *scikit*.
#
# ### Anaconda
# <img align='right' style="height: 60px;" src='https://upload.wikimedia.org/wikipedia/en/c/cd/Anaconda_Logo.png'>
#
# Anaconda es un *toolkit* para *python* y *R* utilizado para modelos e implementaciones de ciencia de datos, distribuido en una versión *open source* y tres versiones de mayor nivel. Anaconda importa algunas de las librerías más utilizadas para la construcción de modelos ML. También facilita el trabajo con interfaces gráficas y visualizaciones, entre otras características.
#
# ### Jupyter
# <img align='left' style="height: 100px;" src='https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/1200px-Jupyter_logo.svg.png'>
#
# *Jupyter* es una aplicación web y de escritorio, lo cual significa que se puede utilizar desde un navegador o puede ser ejecutado desde escritorio para desarrollo. El proyecto es *open source* y es desarrollado públicamente, y se distribuye a través de *JupyterLab*, para desarrollar y respaldar flujos de trabajo para ciencia de datos y ML. *Jupyter Notebook* es una herramienta simple y poderosa que se utiliza para trabajar con problemas de análisis de datos. Esta aplicación permite a los usuarios escribir descripciones de texto, código *Python* e incrustar gráficos y diagramas directamente en una página web interactiva.
#
# ### Numpy
# <img align='right' style="height: 100px;" src='https://gradfutures.princeton.edu/sites/gradprofdev/files/events/numpylogo_-_gabe_perez-giz.png'>
#
# *Numpy* es una librería de *python* que ayuda a implementar funciones relacionadas a modelos estadísticos, ciencias de datos, y varios otros, separados por módulos. Soporta matrices y tablas multidimensionales para realizar cómputo numérico. Una de las implementaciones más famosas de *numpy* en conjunto con otras librerías es la célebre imagen de un agujero negro por el *Event Horizon Telescope*. La instalación de *numpy* se puede llevar a cabo a través de *conda* o *pip*, y generalmente sólo requiere que se importen las librerías necesarias al código. También viene incluida en *Anaconda*.
# ### Pandas
# <img align='left' style="height: 60px;" src='https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png'>
# *Pandas* es otra herramienta útil para el análisis de datos, construida a partir del paquete de *numpy* y también incluida en *Anaconda*. Ofrece estructuras de datos y procesamiento y manipulación de tablas numéricas y series temporales, además de soporte para importar archivos JSON, CSV, SQL o hasta libretas de *Excel*. *Pandas* también puede ser instalada a través de *pip*, *conda*, o el paquete de *Anaconda*.
#
# ### MatplotLib
# <img align='right' style="height: 100px;" src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRLTUxWssq5rtESeIXIEHefdx45-z0yb7D0xQ&usqp=CAU'>
#
# *MatplotLib* es una librería open source utilizada para crear visualizaciones de datos comprensivas en *Python*. Permite a su usuario generar visualizaciones con solo unas pocas líneas de código. Los gráficos dibujados se pueden incrustar fácilmente en *Jupyter Notebook* por lo que siempre se pueden visualizar datos y resultados obtenidos de modelos. La documentación oficial incluye varios ejemplos orientados a casos diferentes y particulares.

# %% [markdown]
# ## Tema a desarrollar
#
# <img align='right' style="width: 100%;" src='https://www.clacso.org/wp-content/uploads/2020/07/Mexico-pandemia.jpeg'>
# <br></br>
# La pandemia causada por el coronavirus, SARS-CoV-2, se ha convertido en uno de los mayores desafíos de salud en todo el mundo. Hay más de 46 millones de casos confirmados y más de 1 millón de muertes al 1 de noviembre de 2020. Esto hace que la pandemia de COVID-19 sea uno de los problemas de salud pública con un impacto significativo en la historia de la humanidad.
#
# El COVID-19 suele ser asintomático[<sup>1</sup>](#Lin). Los pacientes asintomáticos con COVID-19 con frecuencia mejoran con el tiempo sin atención médica especializada[<sup>2</sup>](#Ma). Pero una proporción significativa de los casos de COVID-19 desarrollan neumonía e insuficiencia respiratoria aguda grave[<sup>3</sup>](#Wu). Estos casos suelen requerir hospitalización, ingreso en la unidad de cuidados intensivos e intubación.
#
# La edad avanzada, la presencia de comorbilidades, en particular la hipertensión, la diabetes, la obesidad y el tabaquismo pueden ser factores que aumentan el riesgo de enfermedad grave y es parte de lo que se analizará en este proyecto. Las características de COVID-19 pueden variar según los perfiles demográficos y epidemiológicos de cada país. En el caso específico de México, según Datos del INEGI, en 2015 había 23.4 millones personas mayores de 50 años y de estas 12.4 millones, personas adultas mayores de 60 años (10.4% del total nacional)[<sup>4</sup>](#Granados), además existe una alta tasa de enfermedades crónicas que pueden incrementar el riesgo de complicaciones fatales.[<sup>5</sup>](#Barba)
#
# Evaluar la tasa instantánea de muerte en cualquier momento durante el seguimiento de los factores de riesgo específicos es fundamental para determinar la idoneidad de las estrategias de mitigación y establecer prioridades para controlar la epidemia de COVID-19. Esto es especialmente cierto para los países que están centrando sus esfuerzos en la lucha contra la pandemia; este es el caso de México.
#
# Actualmente, México es el 4<sup>to</sup> con más muertes por COVID-19, sólo detrás de India(123k), Brazil(160k) y Estados Unidos(231k). En Méxicon van 91,753 muertes confirmadas. Una suma que puede explicarse por la alta proporción de personas mayores de 50 años y la alta tasa de enfermedades crónicas.
#
# El objetivo es aplicar disntintas herramientas de machine learning para **encontrar el mejor modelo que nos ayude a predecir las probabilidades que tiene una persona de sobrevivir si resulta ser positivo al SARS-CoV-2**.
#
# ---
#
# <p id="Lin"><a href="https://doi.org/10.1016/j.clinimag.2020.02.008" target="_blank"><sup>1</sup> (Lin, C., Ding, Y., Xie, B., Sun, Z., Li, X., Chen, Z., & Niu, M., 2020)</a></p>
# <p id="Ma"><a href="https://doi.org/10.1016/j.micinf.2020.04.011" target="_blank"><sup>2</sup> (Ma, Y., Xu, Q., Wang, F., Ma, X., Wang, X., Zhang, X., & Zhang, Z., 2020)</a></p>
# <p id="Wu"><a href="https://doi.org/10.1001/jama.2020.2648" target="_blank"><sup>3</sup> (Wu, Z., & McGoogan, J. M., 2020)</a></p>
# <p id="Granados"><a href="https://www.24-horas.mx/2019/03/03/segmento-de-adultos-mayores-es-el-que-tiene-mas-incremento-en-mexico/" target="_blank"><sup>4</sup> (Granados, A.,  2020)</a></p>
# <p id="Granados"><a href="https://www.medigraphic.com/pdfs/patol/pt-2018/pt181a.pdf" target="_blank"><sup>5</sup> (Barba, J.,  2018)</a></p>

# %% [markdown]
# ## Dataset Seleccionado
#
# ### Referencia al repositorio de extracción
#
# Los datos usados en este notebook fueron obtenidos del portal de [Datos Abiertos de México](https://datos.gob.mx). La base de datos de **Covid-19** es actualizada diariamente y se puede consultar en este [Link](https://www.gob.mx/salud/documentos/datos-abiertos-152127). La base de datos y el diccionario de datos a utilizar (por el momento) fueron descargados del link anterior y cuenta con datos actualizados hasta el 31 de octubre. El dataset se encuentra en el [repositorio de *GitHub*](https://github.com/JaimeSolisS/proyecto-ml-tc2006/blob/main/covid31oct.csv) de este proyecto.
#
# ### Descripción del dataset
#
# El dataset contiene todos los casos registrados hasta el momento. Su estructura está formada por 38 variables que describen los más de 2 millones de registros (2,403,499 exactamente). Cada registro es una persona con síntomas.
#
# El dataset contiene registros de casos entre el 1 de enero y el 31 de octubre, con las siguientes categorías:
#
#  - Positivo a SARS-COV-2
#  - No positivo SARS-COV-2
#  - Resultado pendiente
#  - Resultado no adecuado
#  - Caso sin muestra
#
# Como se trata de información real y abierta, el dataset no cuenta con información personal para identificar a las personas.
#
# #### Descripción de variables
#
# A continuación se muestran las variables con su descripción:
#
# |Variable             |Tipo           |Descripción                                                               |
# |:--------------------|:--------------|:-------------------------------------------------------------------------|
# |FECHA_ACTUALIZACION  |Fecha          |La base de datos se alimenta diariamente, esta variable permite                                                    identificar la fecha de la ultima actualizacion.                          |
# |ID_REGISTRO          |Texto          | Número indentificador del caso                                           |
# |ORIGEN               |Categórica     | La vigilancia centinela se realiza a través del sistema de unidades de                                             salud monitoras de enfermedades respiratorias (USMER). Las USMER incluyen                                         unidades médicas del primer, segundo o tercer nivel de atención y también                                         participan como USMER las unidades de tercer nivel que por sus                                                     características contribuyen a ampliar el panorama de información                                                   epidemiológica, entre ellas las que cuenten con especialidad de                                                   neumología, infectología o pediatría. <br> Esta variable asume 3                                                   categorías: <br>1 - USMER<BR>2 - FUERA DE USMER<BR>99 - NO ESPECIFICADO  |
# |SECTOR                |Categórica    |Identifica el tipo de institución del Sistema Nacional de Salud que brindó                                         la atención. <br> Esta variable asume 14  categorías: <br>  1 - CRUZ ROJA                                         <BR>2 - DIF<BR>3 - ESTATAL <br> 4 -  IMSS <br> 5 - IMSS-BIENESTAR <br> 6 -                                          ISSSTE <br> 7 - MUNICIPAL <br> 8 - PEMEX <br> 9 - PRIVADA <br> 10 -                                                SEDENA <br> 11 - SEMAR <br>  12 - SSA <br> 13 - UNIVERSITARIO <br> 99 -                                            NO ESPECIFICADO                                                         |
# |ENTIDAD_UM             |Categórica   |Identifica la entidad donde se ubica la unidad medica que brindó la                                              atención. <br> Esta variable asume 36 categorías:<br>1-32 - Estados de la                                          républica por orden alfabético <BR>  36 - ESTADOS UNIDOS MEXICANOS                                                      <BR>97 - NO APLICA <br> 98 - SE IGNORA <br> 99 - NO ESPECIFICADO    |
# |SEXO                   |Categórica   | Identifica al sexo del paciente <br> Esta variable asume 3                                                        categorías: <br>1 - MUJER<br> 2 - HOMBRE <BR> 99 - NO                                                              ESPECIFICADO    |
# |ENTIDAD_NAC            |Categórica   | Identifica la entidad de nacimiento del paciente. <br> Esta                                                        variable asume 36 categorías:                                                                                      <br>1-32 - Estados de la républica por orden alfabético <BR>                                                       36 - ESTADOS UNIDOS MEXICANOS <BR>97 - NO APLICA <br> 98 -                                                         SE IGNORA <br> 99 - NO ESPECIFICADO                          |
# |ENTIDAD_RES             |Categórica  | Identifica la entidad de residencia del paciente <br> Esta                                                        variable asume 36 categorías:                                                                                      <br>1-32 - Estados de la républica por orden alfabético <BR>                                                       36 - ESTADOS UNIDOS MEXICANOS <BR>97 - NO APLICA <br> 98 -                                                         SE IGNORA <br> 99 - NO ESPECIFICADO                          |
# |MUNICIPIO_RES           |Categórica  |Identifica el municipio de residencia del paciente <br> Esta                                                        variable asume 2502 categorías ya hace un join de la clave                                                       del municipio con la clave de la entidad así como no                                                               especififcado, no aplica y se ignora.                        |
# |TIPO_PACIENTE           |Categórica   | Identifica el tipo de atención que recibió el paciente en la                                                      unidad. Se denomina como ambulatorio si regresó a su casa o                                                        se denomina como hospitalizado si fue ingresado a                                                                  hospitalización. <br> Esta variable asume 3 categorías:                                                            <br>1 - AMBULATORIO <BR> 2 - HOSPITALIZADO <br> 99 - NO                                                            ESPECIFICADO                                                |
# |FECHA_INGRESO             |Fecha      | Identifica la fecha de ingreso del paciente a la unidad de                                                         atención.                                                    |
# |FECHA_SINTOMAS            |Fecha      | Idenitifica la fecha en que inició la sintomatología del                                                          paciente.                                                   |
# |FECHA_DEF                 |Fecha          | Identifica la fecha en que el paciente falleció.            |
# |INTUBADO                  |Categórica | Identifica si el paciente requirió de intubación.<br> Esta                                                         variable asume 5 categorías: <br> 1 - SI<br> 2 - NO<br> 97 -                                                     NO APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO     |
# |NEUMONIA                  |Categórica | Identifica si al paciente se le diagnosticó con neumonía.<br>                                                      Esta variable asume 5 categorías: <br> 1 - SI<br> 2 - NO<br>                                                      97 - NO APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO |
# |EDAD                      |Númerica   | Identifica la edad del paciente                           |
# |NACIONALIDAD              |Categórica | Identifica si el paciente es mexicano o extranjero.       |
# |EMBARAZO                  |Categórica  | Identifica si la paciente está embarazada. <br> Esta                                                              variable asume 5 categorías: <br> 1 - SI<br> 2 - NO<br> 97                                                       - NO APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO   |
# |HABLA_LENGUA_INDIG        |Categórica  |Identifica si el paciente habla lengua índigena.<br> Esta                                                              variable asume 5 categorías: <br> 1 - SI<br> 2 - NO<br> 97                                                       - NO APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO   |
# |INDIGENA                  |Categórica  |Identifica si el paciente se autoidentifica como una persona                                                      indígena. <br> Esta variable asume 5 categorías: <br> 1 -SI<br>                                                     2 - NO<br> 97 - NO APLICA <br> 98 - SE IGNORA <br>99 - NO                                                         ESPECIFICADO                                                 |
# |DIABETES                  |Categórica  |Identifica si el paciente tiene un diagnóstico de diabetes.<br> Esta                                               variable asume 5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA                                            <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO      |
# |EPOC                      |Categórica   |Identifica si el paciente tiene un diagnóstico de EPOC. <br> Esta                                                 variable asume 5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA                                            <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO  |
# |ASMA                      |Categórica    |Identifica si el paciente tiene un diagnóstico de asma.  <br> Esta                                                 variable asume 5 categorías: <br> 1 -SI<br>2 - NO<br> 97 - NO APLICA                                              <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO                |
# |INMUSUPR                  |Categórica    |Identifica si el paciente presenta inmunosupresión.<br> Esta variable                                              asume 5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA <br> 98 -                                            SE IGNORA <br>99 - NO  ESPECIFICADO                                  |
# |HIPERTENSION              |Categórica     |Identifica si el paciente tiene un diagnóstico de hipertensión. <br>                                               Esta variable asume 5 categorías: <br> 1 -SI<br>  2 - NO<br> 97 - NO                                                APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO |
# |OTRAS_COM                 |Categórica     |Identifica si el paciente tiene diagnóstico de otras enfermedades.                                                 <br> Esta variable asume 5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 -                                             NO APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO               |
# |CARDIOVASCULAR             |Categórica    |Identifica si el paciente tiene un diagnóstico de enfermedades                                                      cardiovasculares.  <br> Esta variable asume 5 categorías: <br> 1 -                                                SI<br> 2 - NO<br> 97 - NO APLICA <br> 98 - SE IGNORA <br>99 - NO                                                   ESPECIFICADO                                                 |
# |OBESIDAD                  |Categórica     |Identifica si el paciente tiene diagnóstico de obesidad.<br> Esta                                                  variable asume 5 categorías: <br> 1 -SI<br>2 - NO<br> 97 - NO APLICA                                             <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO  |
# |RENAL_CRONICA             |Categórica     |Identifica si el paciente tiene diagnóstico de insuficiencia renal                                                 crónica.<br> Esta variable asume 5 categorías: <br> 1 -SI<br>                                                     2 - NO<br> 97 - NO APLICA <br> 98 - SE IGNORA <br>99 - NO                                                         ESPECIFICADO                                                 |
# |TABAQUISMO                |Categórica     |Identifica si el paciente tiene hábito de tabaquismo.<br> Esta                                                      variable asume 5 categorías: <br> 1 -SI<br>  2 - NO<br> 97 - NO                                                   APLICA <br> 98 - SE IGNORA <br>99 - NO ESPECIFICADO      |
# |OTRO_CASO                 |Categórica     |Identifica si el paciente tuvo contacto con algún otro caso                                                       diagnósticado con SARS CoV-2<br> Esta variable asume 5 categorías:                                                  <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA <br> 98 - SE IGNORA <br>99 -                                              NO ESPECIFICADO                                                 |
# |TOMA_MUESTRA              |Categórica     |Identifica si al paciente se le tomó muestra.<br> Esta variable asume                                             5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA <br> 98 - SE                                               IGNORA <br>99 - NO ESPECIFICADO                       |
# |RESULTADO_LAB             |Categórica     |Identifica el resultado del análisis de la muestra reportado por el                                               laboratorio de la Red Nacional de Laboratorios de Vigilancia                                                        Epidemiológica (INDRE, LESP y LAVE) y laboratorios privados avalados                                               por el InDRE cuyos resultados son registrados en SISVER. <br> Esta                                                variable asume 5 categorías: <br> 1 - POSITIVO A SARS-COV-2<br> 2 -                                                 NO POSITIVO A SARS-COV-2<br> 3 - RESULTADO PENDIENTE <br> 4 -                                                     RESULTADO NO ADECUADO  <br>97 - NO APLICA (CASO SIN MUESTRA)       |
# |CLASIFICACION_FINAL        |Categórica     |Identifica si el paciente es un caso de COVID-19 según el catálogo                                                "CLASIFICACION_FINAL". <br> Esta variable asume 7 categorías: <br> 1                                               - CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA                                                               EPIDEMIOLÓGICA<br> 2 - CASO DE COVID-19 CONFIRMADO POR COMITÉ DE                                                   DICTAMINACIÓN<br> 3 - CASO DE SARS-COV-2  CONFIRMADO POR LABORATORIO                                               <br> 4 - INVÁLIDO POR LABORATORIO  <br>5 - NO REALIZADO POR                                                       LABORATORIO <br> 6 - CASO SOSPECHOSO <br> 7 - NEGATIVO A SARS-COV-2                                                POR LABORATORIO                                                  |
# |MIGRANTE                   |Categórica     |Identifica si el paciente es una persona migrante.<br> Esta variable                                              asume 5 categorías: <br> 1 -SI<br> 2 - NO<br> 97 - NO APLICA <br> 98                                               - SE IGNORA <br>99 - NO ESPECIFICADO                              |
# |PAIS_NACIONALIDAD          |Texto          |Identifica la nacionalidad del paciente.|
# |PAIS_ORIGEN                |Texto          |Identifica la nacionalidad del paciente.|
# |UCI                        |Categórica     | Identifica si el paciente requirió ingresar a una Unidad de Cuidados                                              Intensivos.<br> Esta variable asume 3 categorías: <br> 1 -SI<br>                                                  2 - NO<br> 97 - NO APLICA<br> 98 - SE IGNORA<br>99 - NO ESPECIFICADO|

# %% [markdown]
# ## Librerías

# %%
import pandas as pd

# %% [markdown]
# ## Preprocesamiento de Datos

# %%
rawData = pd.read_csv("https://media.githubusercontent.com/media/JaimeSolisS/proyecto-ml-tc2006/main/dataset/covid31oct.csv", encoding = "ISO-8859-1")

# %%
rawData2 = pd.read_csv("dataset/covid31oct.csv", encoding = "ISO-8859-1")

# %%
print("Shape:", rawData.shape)
rawData.info()
# Out:
# Shape: (2403499, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2403499 entries, 0 to 2403498
# Data columns (total 38 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FECHA_ACTUALIZACION  object
#  1   ID_REGISTRO          object
#  2   ORIGEN               int64
#  3   SECTOR               int64
#  4   ENTIDAD_UM           int64
#  5   SEXO                 int64
#  6   ENTIDAD_NAC          int64
#  7   ENTIDAD_RES          int64
#  8   MUNICIPIO_RES        int64
#  9   TIPO_PACIENTE        int64
#  10  FECHA_INGRESO        object
#  11  FECHA_SINTOMAS       object
#  12  FECHA_DEF            object
#  13  INTUBADO             int64
#  14  NEUMONIA             int64
#  15  EDAD                 int64
#  16  NACIONALIDAD         int64
#  17  EMBARAZO             int64
#  18  HABLA_LENGUA_INDIG   int64
#  19  INDIGENA             int64
#  20  DIABETES             int64
#  21  EPOC                 int64
#  22  ASMA                 int64
# ...

# %% [markdown]
# El dataset contiene **2403499 registros y 38 variables**. La variable objetivo (Fallecimiento) debera ser creada en la sección de Feature Engineering. 7 variables son de tipo *object* y el resto son de tipo *entero*. Además podemos ver que no tenemos valores nulos en las variables.

# %%
pd.options.display.max_columns = None
rawData.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-10-31      043f64       2       4           9     2
# 1          2020-10-31      0e07d8       1       4          15     2
# 2          2020-10-31      13757c       1      12          15     1
# 3          2020-10-31      002371       1       4           3     2
# 4          2020-10-31      11fb00       1      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0            9            9             10              2    2020-03-26
# 1           15           15            104              2    2020-03-28
# 2           15           15            106              1    2020-03-31
# 3            3            3              8              1    2020-03-31
# 4            9            9             15              1    2020-03-29
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# ...

# %% [markdown]
# De la tabla anterior podemos notar algunas cosas, como se mencionó anteriormente, tendremos que **crear la variable objetivo** así como algunas otras variables que nos sean útiles, así como asegurarnos de que las variables a utilizar sean todas **númericas** para que los algoritmos con los que entrenaremos los modelos puedan procesarlos. Además tendremos que ser cuidadosos con los rangos de las variables para que estén **apróximadamente en la misma escala**. También podemos notar y como se estableció en la descripción de las variables, que algunos valores implican que se ignora o no se especifica el dato, lo que vendría siendo lo mismo a tener **datos nulos**, por lo que tendremos que lidiar con ellos.

# %% [markdown]
# ## Referencias
#
# Al-Turaiki, I., Alshahrani, M., & Almutairi, T. (2016). *Building predictive models for MERS-CoV infections using data mining techniques*. Journal of Infection and Public Health, 9(6), 744–748. [DOI](https://doi.org/10.1016/j.jiph.2016.09.007)
#
# Anaconda Inc. (s.f.). *Anaconda Your data science toolkit*. Recuperado el 18 de septiembre de 2020, de Anaconda:[URL](https://www.anaconda.com/products/individual)
#
# Barba, J. *México y el reto de las enfermedades crónicas no transmisibles. El laboratorio también juega un papel importante*. Rev Mex Patol Clin Med Lab. 2018;65(1):4-17.[URL](https://www.medigraphic.com/pdfs/patol/pt-2018/pt181a.pdf)
#
# Barranco, R. (2012). *¿Qué es Big Data?* Recuperado el 18 de septiembre de 2020, de IBM Developer: [URL](https://developer.ibm.com/es/technologies/data-science/articles/que-es-big-data/)
#
# Bijaya, B. (2019). *Introduction To Machine Learning using Python*. Recuperado el 18 de septiembre de 2020, de Geeks for Geeks: [URL](https://www.geeksforgeeks.org/introduction-machine-learning-using-python/)
#
# Chollet, F. (2018). *Deep Learning with Python*. Manning Publications Co.
#
# Granados, A. (2019). *Segmento de adultos mayores es el que tiene más incremento en México*.  Recuperado el 1 de noviembre de 2020, de 24 horas: [URL](https://www.24-horas.mx/2019/03/03/segmento-de-adultos-mayores-es-el-que-tiene-mas-incremento-en-mexico/)
#
# Lin, C., Ding, Y., Xie, B., Sun, Z., Li, X., Chen, Z., & Niu, M. (2020). *Asymptomatic novel coronavirus pneumonia patient outside Wuhan: The value of CT images in the course of the disease*. Clinical Imaging, 63, 7–9.[DOI](https://doi.org/10.1016/j.clinimag.2020.02.008)
#
# Ma, Y., Xu, Q., Wang, F., Ma, X., Wang, X., Zhang, X., & Zhang, Z. (2020). *Characteristics of asymptomatic patients with SARS-CoV-2 infection in Jinan, China*. Microbes and Infection, 22(4–5), 212–217.[DOI](https://doi.org/10.1016/j.micinf.2020.04.011)
#
# NumPy. (s.f.). *NumPy*. Recuperado el 18 de septiembre de 2020, de NumPy: [URL](https://numpy.org/)
#
# Patrizio , A. (2018). *IDC: Expect 175 zettabytes of data worldwide by 2025*. Recuperado el 18 de septiembre de 2020, de Network World: [URL](https://www.networkworld.com/article/3325397/idc-expect-175-zettabytes-of-data-worldwide-by-2025.html)
#
# Project Jupyter. (s.f.). *Jupyter*. Recuperado el 18 de septiembre de 2020, de Jupyter:[URL](https://jupyter.org/index.html)
#
# The Pandas Development Team. (s.f.). *IO tools (text, CSV, HDF5, ...)*. Recuperado el 18 de septiembre de 2020, de Pandas: [URL](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-tools-text-csv-hdf5)
#
# Wu, Z., & McGoogan, J. M. (2020). *Characteristics of and Important Lessons From the Coronavirus Disease 2019 (COVID-19) Outbreak in China*. JAMA, 323(13), 1239.[DOI](https://doi.org/10.1001/jama.2020.2648)
